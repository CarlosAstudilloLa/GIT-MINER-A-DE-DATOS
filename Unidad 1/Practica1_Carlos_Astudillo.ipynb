# %%
# LECTURA DE FICHERO DE DATOS Y VISUALIZACIÓN DE DATOS

### Nombre de la asignatura: Minería de Datos - Laboratorio
### Carrera: Big Data
### Estudiante: Carlos Astudillo
### Fecha: 19/05/2024

# %%
import pandas as pd

# %%
df = pd.read_excel("2027_Ocho de Noviembre.xlsx")

# %%
df
# Out:
#    ies_id  codigo_sniese                                nombre_institucion  \
# 0    1135           2027  INSTITUTO SUPERIOR TECNOLÓGICO OCHO DE NOVIEMBRE
# 1    1135           2027  INSTITUTO SUPERIOR TECNOLÓGICO OCHO DE NOVIEMBRE
# 2    1135           2027  INSTITUTO SUPERIOR TECNOLÓGICO OCHO DE NOVIEMBRE
# 3    1135           2027  INSTITUTO SUPERIOR TECNOLÓGICO OCHO DE NOVIEMBRE
# 4    1135           2027  INSTITUTO SUPERIOR TECNOLÓGICO OCHO DE NOVIEMBRE
# 5    1135           2027  INSTITUTO SUPERIOR TECNOLÓGICO OCHO DE NOVIEMBRE
# 6    1135           2027  INSTITUTO SUPERIOR TECNOLÓGICO OCHO DE NOVIEMBRE
# 7    1135           2027  INSTITUTO SUPERIOR TECNOLÓGICO OCHO DE NOVIEMBRE
#
#      codigo_carrera           Carrera nombre_provincia can_nombre  \
# 0  550212Q02-P-0710  DISEÑO DE MODAS            EL ORO      PIÑAS
# 1  550212Q02-P-0710  DISEÑO DE MODAS            EL ORO      PIÑAS
# 2  550212Q02-P-0710  DISEÑO DE MODAS            EL ORO      PIÑAS
# ...

# %%
from ydata_profiling import ProfileReport

# %%
profile=ProfileReport(df,title="8_noviembre")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.4&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-05-20 00:13:12.551461&quot;&gt;&lt;title&gt;MERCADO_LABORAL&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
 import sweetviz as sv

# %%
advert_report = sv.analyze([df, "MERCADO_LABORAL"])
# Out:
#                                              |                                             | [  0%]   00:00 ->…

# %%
advert_report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ![Captura%20de%20pantalla%202024-05-19%20191406.png](attachment:Captura%20de%20pantalla%202024-05-19%20191406.png)

# %%
from powerbiclient import QuickVisualize, get_dataset_config

# %%
from powerbiclient.authentication import DeviceCodeLoginAuthentication

# %%
device_auth=DeviceCodeLoginAuthentication()
# Out:
# Performing device flow authentication. Please follow the instructions below.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code FMT6LGSZV to authenticate.
#
# Device flow authentication successfully completed.
# You are now logged in .
#
# The result should be passed only to trusted code in your notebook.

# %%
PBI_visualizacion=QuickVisualize(get_dataset_config(df), auth=device_auth)

# %%
PBI_visualizacion
# Out:
# QuickVisualize()
